# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('C:/Users/yasin/Desktop/hotel_reviews.csv/hotel_reviews.csv')

# %%
df1
# Out:
#       Index             Name                    Area Review_Date  \
# 0         0  Hotel The Pearl    Paharganj, New Delhi      Jul-23
# 1         1  Hotel The Pearl    Paharganj, New Delhi      Aug-23
# 2         2  Hotel The Pearl    Paharganj, New Delhi      Aug-23
# 3         3  Hotel The Pearl    Paharganj, New Delhi      Aug-23
# 4         4  Hotel The Pearl    Paharganj, New Delhi      Aug-23
# ...     ...              ...                     ...         ...
# 6996   6996  FabHotel F9 NSP  North Delhi, New Delhi      Aug-23
# 6997   6997  FabHotel F9 NSP  North Delhi, New Delhi      Jul-23
# 6998   6998  FabHotel F9 NSP  North Delhi, New Delhi      Jul-23
# 6999   6999  FabHotel F9 NSP  North Delhi, New Delhi      Jun-23
# 7000   7000  FabHotel F9 NSP  North Delhi, New Delhi      Jul-23
#
#                                Rating_attribute  Rating(Out of 10)  \
# 0                    Best budget friendly hotel                9.0
# ...

# %%
secilen_sutun = df["Review_Text"]

# %%
secilen_sutun
# Out:
# 0       Hotel the pearl is perfect place to stay in De...
# 1       Location of the hotel is perfect. The hotel is...
# 2                                  Location, Indian food.
# 3       The location and the hotel itself is great. Ne...
# 4       Friendly and smiling staffs.. The reception st...
#                               ...
# 6996    The room was good, comfortable and aesthetic \...
# 6997                                           good hotel
# 6998    good experience for me about hotel \nvery good...
# 6999                                            well done
# 7000                                              Nothing
# Name: Review_Text, Length: 7001, dtype: object

# %%
restoran = pd.read_csv("C:/Users/yasin/Desktop/tripadvisor_hotel_reviews.csv/trip advisor restaurents  10k - trip_rest_neywork_1.csv")

# %%
restoran
# Out:
#                                          Title Number of review  \
# 0                 All Stars Sports Bar & Grill               21
# 1                                   Olio e Piu            2,998
# 2                       Boucherie West Village            1,465
# 3                            Club A Steakhouse            4,413
# 4                    Piccola Cucina Estiatorio              403
# ...                                        ...              ...
# 10392                        The Sandwich Slut               No
# 10393                        The Sandwich Slut               No
# 10394                        The Sandwich Post               No
# 10395                        The Sandwich Cafe               No
# 10396  Lezzet Mediterranean Turkish Restaurant               No
#
#                      Catagory  \
# 0                    Bar, Pub
# 1              Italian, Pizza
# 2          French, Steakhouse
# 3        American, Steakhouse
# 4           Italian, Sicilian
# ...

# %%
restoran.columns
# Out:
# Index(['Title', 'Number of review', 'Catagory', 'Reveiw Comment',
#        'Popular food', 'Online Order'],
#       dtype='object')

# %%
yorum= restoran['Reveiw Comment']

# %%
yorum
# Out:
# 0             “The fries were terrific also, hot crisp...”
# 1                  “I love the food and our server Maria!”
# 2        “The filet mignon was impeccable and the musse...
# 3        “My seafood cocktail had wonderful large lump ...
# 4        “penne al pomodoro and bucatini cacio e pepe w...
#                                ...
# 10392                                                   No
# 10393                                                   No
# 10394                                                   No
# 10395                                                   No
# 10396                                                   No
# Name: Reveiw Comment, Length: 10397, dtype: object

# %%
df_birlesik = pd.concat([yorum, secilen_sutun], ignore_index=True)  # ignore_index=True, indekslerin yeniden düzenlenmesini sağlar

# %%
df_birlesik
# Out:
# 0             “The fries were terrific also, hot crisp...”
# 1                  “I love the food and our server Maria!”
# 2        “The filet mignon was impeccable and the musse...
# 3        “My seafood cocktail had wonderful large lump ...
# 4        “penne al pomodoro and bucatini cacio e pepe w...
#                                ...
# 17393    The room was good, comfortable and aesthetic \...
# 17394                                           good hotel
# 17395    good experience for me about hotel \nvery good...
# 17396                                            well done
# 17397                                              Nothing
# Length: 17398, dtype: object

# %%
df_birlesik.to_csv('birlesik_yorumlar.csv', index=False, encoding='utf-8')  # index=False, indeksin dosyaya yazılmasını engeller
